# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pickle

# %%
import numpy as np
import pandas as pd

from sklearn.decomposition import PCA

from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import svm

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from sklearn.cluster import DBSCAN, SpectralClustering, MeanShift
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.cluster import KMeans

plt.style.use("seaborn")
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', 1000)
pd.set_option('max_rows', 600)

# %%
df_data = pd.read_pickle('./data/df_data_all.pkl')

# %%
# df_data.info()

# %%
cols_keep = ['Player','Team', 'GP', 'W', 'L', 'MIN', 'catch_shoot%', 'offense_transition Freq', 'pullupFGA%', 'offense_isolation Freq',
 'offense_ball_handler Freq', 'offense_roll_man Freq', 'offense_playtype_post_up Freq', 'offense_spot_up Freq', 'offense_hand_off Freq',
 'offense_cut Freq', 'offense_off_screen Freq', 'offense_playtype_misc Freq', 'off_misc Freq', 'defender02ft Freq', 'defender24ft Freq',
 'defender46ft Freq', 'defender6pft Freq', 'off_reb AdjustedOREBChance%', 'off_reb AVGOREBDistance',  'def_reb AdjustedDREBChance%',  'def_reb AVGDREBDistance',
 'def_isolation Freq', 'def_isolation SFFreq', 'def_ball_handler Freq', 'def_ball_handler SFFreq', 'def_playtype_post_up Freq', 'def_playtype_post_up SFFreq', 'def_spot_up Freq',
 'def_spot_up SFFreq', 'def_hand_off Freq', 'def_hand_off SFFreq', 'def_off_screen Freq', 'def_off_screen SFFreq', 'passesMade_div_Received %',
 'touches AvgSecPerTouch', 'touches AvgDribPerTouch', 'touches ElbowTouches%', 'touches PostUps%', 'touches PaintTouches%', 'AvgSpeedOff',
 'AvgSpeedDef']

# %%
df_data = df_data.fillna(0)

# %%
df_data_min = df_data[cols_keep]

# %%
df_data_min = df_data_min.set_index('Player')
df_data_min['total_min'] = df_data_min['GP'].multiply(df_data_min['MIN'])
df_data_min = df_data_min[df_data_min['total_min'].apply(lambda x: float(x)) > 1000]
df_data_min = df_data_min[df_data_min['GP'].apply(lambda x: float(x)) > 41]
df_data_min = df_data_min.drop('total_min',axis=1)
# df_data_min.to_pickle('./data/df_data_min.pkl')

# %%
cols_rename = ['Team', 'GP', 'W', 'L', 'Min', 'Catch Shoot', 'Fast Break', 'Pull Up Shot Percent', 'Offense Isolation',
 'Offense Ballhandler', 'Offense Rollman', 'Offense Post Up', 'Offense Spot Up Shot', 'Offense Hand Off',
 'Offense Cut', 'Offense Offscreen', 'Offense Playtype Misc', 'Offense Misc', 'Closely Contested Shot',
 'Contested Shot', 'Open Shot', 'Wide Open Shot', 'Offense Rebounding Adjchance', 'Offense Rebounding Distance',
 'Defense Rebounding Adjchance', 'Defense Rebounding Distance', 'Defense Isolation Freq', 'Defense Isolation Shot Freq',
 'Defense Ball_Handler Freq', 'Defense Ball_Handler Shot Freq', 'Defense Post Up Freq', 'Defense Post Up Shot Freq',
 'Defense Spot Up Freq', 'Defense Spot Up Shot Freq', 'Defense Handoff Freq', 'Defense Shot Freq', 'Defense Offscreen Freq',
 'Defense Offscreen Shot Freq', 'Passes Made Over Passes Received Percent', 'Average Seconds Per Touch', 'Average Dribbles Per Touch',
 'Elbow Touches Percent', 'Post Up Touches Percent', 'Paint Touches Percent', 'Average Speed Offense', 'Average Speed Defense']

# %%
df_data_min.columns = cols_rename

# %%
df_data_min
# Out:
#                          Team    Gp   W   L   Min  Catch Shoot  Fastbreak  \
# Player
# Jrue Holiday              NOP  67.0  30  37  35.9     0.121387       16.4
# Bradley Beal              WAS  81.0  31  50  36.9     0.233161       20.9
# Paul George               OKC  76.0  45  31  36.9     0.280952       20.6
# Zach LaVine               CHI  62.0  16  46  34.4     0.111732       14.1
# Josh Richardson           MIA  73.0  35  38  34.8     0.368794       11.3
# CJ McCollum               POR  70.0  43  27  33.9     0.203390       13.8
# Buddy Hield               SAC  82.0  39  43  31.9     0.325301       26.1
# Tobias Harris             PHI  82.0  46  36  34.7     0.235294       13.1
# Kyle Kuzma                LAL  70.0  33  37  33.0     0.354839       23.1
# Brandon Ingram            LAL  52.0  25  27  33.9     0.171429       18.8
# Mike Conley               MEM  70.0  30  40  33.5     0.187500       11.6
# Jimmy Butler              PHI  64.0  38  26  33.5     0.152174       16.6
# ...

# %%
df_data_min.to_pickle('./data/df_data_added_min.pkl')

# %%
df_data_min = pd.read_pickle('./data/df_data_added_min.pkl')

# %%
df_data_min.columns
# Out:
# Index(['Team', 'GP', 'W', 'L', 'Min', 'Catch Shoot', 'Fast Break',
#        'Pull Up Shot Percent', 'Offense Isolation', 'Offense Ballhandler',
#        'Offense Rollman', 'Offense Post Up', 'Offense Spot Up Shot',
#        'Offense Hand Off', 'Offense Cut', 'Offense Offscreen',
#        'Offense Playtype Misc', 'Offense Misc', 'Closely Contested Shot',
#        'Contested Shot', 'Open Shot', 'Wide Open Shot',
#        'Offense Rebounding Adjchance', 'Offense Rebounding Distance',
#        'Defense Rebounding Adjchance', 'Defense Rebounding Distance',
#        'Defense Isolation Freq', 'Defense Isolation Shot Freq',
#        'Defense Ball_Handler Freq', 'Defense Ball_Handler Shot Freq',
#        'Defense Post Up Freq', 'Defense Post Up Shot Freq',
#        'Defense Spot Up Freq', 'Defense Spot Up Shot Freq',
#        'Defense Handoff Freq', 'Defense Shot Freq', 'Defense Offscreen Freq',
#        'Defense Offscreen Shot Freq',
# ...
